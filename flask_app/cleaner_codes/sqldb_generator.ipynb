# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite://', echo=False)
import sqlite3, csv
import pandas as pd
import numpy as np

# %%
conn =sqlite3.connect('clean_data.db')

# %%
c = conn.cursor()
c.execute('''CREATE TABLE recipe_table 
(recipe_id int, recipe_name text, ingredients text, cooking_directions text, prep_time real, cook_time real, total_time real, Difficulty text)''')

# %%
recipe_table=pd.read_csv('clean_data.csv')

# %%
cur.execute('''SELECT * FROM df''').fetchall
# Out:
# <function Cursor.fetchall>

# %%
df=pd.read_csv('clean_data.csv')

# %%
recipe_table.to_sql('recipe_table', conn, if_exists='append', index=False)

# %%
c.execute('''SELECT * FROM recipe_table''').fetchall()
# Out:
# [(240488,
#   'Pork Loin, Apples, and Sauerkraut',
#   'sauerkraut drained^Granny Smith apples sliced^large onion^caraway seeds^apple cider divided^brown sugar^Rub:^Thai seasoning^salt^garlic powder^ground black pepper^boneless pork loin roast',
# ...

# %%
df
# Out:
#        recipe_id                              recipe_name  \
# 0         240488        Pork Loin, Apples, and Sauerkraut
# 1         218939         Foolproof Rosemary Chicken Wings
# 2          87211                    Chicken Pesto Paninis
# 3         245714                       Potato Bacon Pizza
# 4         218545  Latin-Inspired Spicy Cream Chicken Stew
# ...          ...                                      ...
# 40490     222886                   Grateful Dead Cocktail
# 40491      25650              Cheese Filling For Pastries
# 40492      23544                           Peach Smoothie
# 40493     170710                      Double Dare Peaches
# 40494      79774               All-Purpose Marinara Sauce
#
#                                              ingredients  \
# 0      sauerkraut drained^Granny Smith apples sliced^...
# 1      chicken wings^sprigs rosemary^head garlic^oliv...
# 2      focaccia bread quartered^prepared basil pesto^...
# ...
