# %%
import pandas as pd

# %%
RD = pd.read_csv('Happycook/raw-data_recipe.csv')

# %%
print(RD.shape)
# Out:
# (49698, 9)

# %%
print(RD.columns)
# Out:
# Index(['recipe_id', 'recipe_name', 'aver_rate', 'image_url', 'review_nums',
#        'ingredients', 'cooking_directions', 'nutritions', 'reviews'],
#       dtype='object')

# %%
print(RD.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49698 entries, 0 to 49697
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   recipe_id           49698 non-null  int64
#  1   recipe_name         49698 non-null  object
#  2   aver_rate           49698 non-null  float64
#  3   image_url           49698 non-null  object
#  4   review_nums         49698 non-null  int64
#  5   ingredients         49698 non-null  object
#  6   cooking_directions  49698 non-null  object
#  7   nutritions          49698 non-null  object
#  8   reviews             49698 non-null  object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 3.4+ MB
# None

# %%
RD.sort_values(by="aver_rate", ascending=False).head(10)
# Out:
#        recipe_id                            recipe_name  aver_rate  \
# 0         222388                         Homemade Bacon        5.0
# 36740     233859  Groovy 'Who Brought That' Pasta Salad        5.0
# 36744     216807    Aunt Karen's Brussels Sprouts Salad        5.0
# 36751     259303     Polish Sauerkraut and Carrot Salad        5.0
# 36755     238354                    Vegan Chilean Salad        5.0
# 36759     258123         Peach and Tomato Caprese Salad        5.0
# 46739     228490       Peachy Keen Long Island Iced Tea        5.0
# 36763     255849                 Quick Smoky Kale Salad        5.0
# 46738     246303             Deep-Fried Morel Mushrooms        5.0
# 36764     222944               Drunken Grapefruit Salad        5.0
#
#                                                image_url  review_nums  \
# 0      https://images.media-allrecipes.com/userphotos...            3
# 36740  https://images.media-allrecipes.com/userphotos...            3
# ...

# %%
import re

# %%
data = RD

# %%
data = data.replace(r'^',' ', regex=True)
#data = data.replace(r'\t','', regex=True)
#data = data.replace(r'\s\s\s','', regex=True)

# %%
data.sort_values(by="aver_rate", ascending=False).head(2)
# Out:
#        recipe_id                             recipe_name  aver_rate  \
# 0         222388                          Homemade Bacon        5.0
# 36740     233859   Groovy 'Who Brought That' Pasta Salad        5.0
#
#                                                image_url  review_nums  \
# 0       https://images.media-allrecipes.com/userphoto...            3
# 36740   https://images.media-allrecipes.com/userphoto...            3
#
#                                              ingredients  \
# 0       pork belly^smoked paprika^kosher salt^ground ...
# 36740   tri-color rotini pasta^water divided^red food...
#
#                                       cooking_directions  \
# 0       {'directions': u'Prep\n5 m\nCook\n2 h 45 m\nR...
# 36740   {'directions': u'Prep\n20 m\nCook\n10 m\nRead...
#
#                                               nutritions  \
# 0       {u'niacin': {u'hasCompleteData': False, u'nam...
# 36740   {u'niacin': {u'hasCompleteData': False, u'nam...
#
# ...

# %%
data = data.dropna(how='any')
data = data.reset_index(drop=True)

# %%
data = data.replace(r'\n',' ', regex=True)
data = data.replace(r'^',' ', regex=True)

# %%
data.sort_values(by="aver_rate", ascending=False).head(2)
# Out:
#        recipe_id                              recipe_name  aver_rate  \
# 0         222388                           Homemade Bacon        5.0
# 36740     233859    Groovy 'Who Brought That' Pasta Salad        5.0
#
#                                                image_url  review_nums  \
# 0        https://images.media-allrecipes.com/userphot...            3
# 36740    https://images.media-allrecipes.com/userphot...            3
#
#                                              ingredients  \
# 0        pork belly^smoked paprika^kosher salt^ground...
# 36740    tri-color rotini pasta^water divided^red foo...
#
#                                       cooking_directions  \
# 0        {'directions': u'Prep\n5 m\nCook\n2 h 45 m\n...
# 36740    {'directions': u'Prep\n20 m\nCook\n10 m\nRea...
#
#                                               nutritions  \
# 0        {u'niacin': {u'hasCompleteData': False, u'na...
# 36740    {u'niacin': {u'hasCompleteData': False, u'na...
#
# ...
